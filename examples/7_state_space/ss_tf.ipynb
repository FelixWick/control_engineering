# %%
import matplotlib.pyplot as plt
import control as ct

# %%
A = [[0, 1], [-1, -0.2]]
B = [[0], [1]]
C = [[1, 0]]
D = [[0]]

# %%
sys_ss = ct.ss(A, B, C, D)

# %%
t, y = ct.step_response(sys_ss)

# same response using transfer function:
# sys_tf = ct.tf(sys_ss)

# %%
plt.grid()
plt.plot(t, y)
