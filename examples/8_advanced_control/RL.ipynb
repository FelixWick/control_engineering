# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
states = np.linspace(-5, 5, 100)
value = -states**2

# %%
plt.plot(states, value)
plt.xlabel("State")
plt.ylabel("Value")
plt.grid()
plt.show()
